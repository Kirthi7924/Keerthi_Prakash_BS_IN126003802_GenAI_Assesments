# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_name = "Qwen/Qwen2.5-0.5B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
def generate_response(messages):
    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )
    model_inputs = tokenizer([text], return_tensors="pt").to(model.device)
    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=80,
        do_sample=True,
        temperature=0.7,
        top_p=0.9
    )
    generated_ids = [
        output_ids[len(input_ids):]
        for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
    ]
    response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return response

# %%
print("Chatbot: Hello! I am your AI assistant. Type 'exit' or 'quit' to stop.")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye! Have a great day.")
        break
    messages.append({"role": "user", "content": user_input})
    response = generate_response(messages)

    print("Chatbot:", response)
# Out:
# Chatbot: Hello! I am your AI assistant. Type 'exit' or 'quit' to stop.
# You:  Hello
# Chatbot: Hello! How may I assist you today?
# You:   What is Artificial Intelligence?
# Chatbot: Artificial intelligence (AI) refers to the ability of machines to perform tasks typically required to be done by a human being. This includes tasks such as perception, reasoning, learning, problem-solving, decision-making, and creativity.
#
# AI involves the development of algorithms and machine learning techniques that allow computers to learn from data, recognize patterns, make predictions or decisions based on new input, and interact with users in
# You:  Who created Python?
# Chatbot: Python was created by Guido van Rossum, an engineer from the Netherlands. He started working on Python in 1989 as part of his PhD thesis at the University of Amsterdam. Python gained popularity through its simplicity and ease of use, making it widely used across various industries. It also supports several programming paradigms, including procedural, object-oriented, functional, and imperative.
#
# - Guid
# You:  Thank you
# Chatbot: You're welcome! If you have any more questions or need further assistance, feel free to ask.
# You:  exit
# Chatbot: Goodbye! Have a great day.
