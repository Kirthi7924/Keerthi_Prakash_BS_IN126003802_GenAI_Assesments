# %% [markdown]
# Task 1 Conceptual Understanding
# 1. What is the difference between "Love" and "love" in NLP?
#     NLP is case sensitive. It treats both "Love" and "love" as different tokens, so converting it to lowercase is required.
#
# 2. What happens if stopwords are not removed?
#     * Dataset becomes huge
#     * Increase noise in data
#     * Makes model less efficient
#     * Reduce accuracy
#
# 3. Provide two real-world scenarios where removing stopwords can be harmful.
#     * In Sentiment analysis
#       eg: I am not happy
#       not removed → different meanings
#       I am happy
#
#     * Question Answering
#       eg: What is your name?
#       What removed → your name
#       different meaning
#
# 4. Explain the difference b/w stemming & lemmatization
#     * Stemming cut words using simple rules
#     * May produce incorrect words
#     * Lemmatization uses vocabulary & grammar rules
#     * Produce meaningful base words

# %% [markdown]
# Task 2:Build Advanced Preprocessing Function

# %%
import re

def preprocess_text(text):
    if not text or not isinstance(text, str):
        return [], ""
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'(.)\1{2,}', r'\1', text)
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    tokens = text.split()
    cleaned_sentence = " ".join(tokens)
    return tokens, cleaned_sentence
    text = input("Enter a sentence:")
tok, cle = preprocess_text(text)
print("Output sentence:", cle)
# Out:
# Output sentence: i have dogs

# %% [markdown]
# Stress Testing

# %%
test_sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]
for sentence in test_sentences:
    tokens, clean = preprocess_text(sentence)
    print("\nOriginal:", sentence)
    print("Tokens:", tokens)
    print("Cleaned:", clean)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Cleaned: get free access now
#
# Original: I absolutely looooved this product 😍😍
# Tokens: ['i', 'absolutely', 'loved', 'this', 'product']
# Cleaned: i absolutely loved this product
#
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Cleaned: worst service ever
#
# Original: Call me at 9876543210
# Tokens: ['call', 'me', 'at']
# Cleaned: call me at
#
# Original: This is THE best course!!!
# Tokens: ['this', 'is', 'the', 'best', 'course']
# Cleaned: this is the best course
#
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Cleaned: visit now
#
# Original: Nooooo this is baaad!!!
# Tokens: ['no', 'this', 'is', 'bad']
# Cleaned: no this is bad
#
# Original: OK OK OK I got it
# Tokens: ['ok', 'ok', 'ok', 'i', 'got', 'it']
# Cleaned: ok ok ok i got it
#
# Original: Win $$$ now!!! Limited offer!!!
# Tokens: ['win', 'now', 'limited', 'offer']
# ...

# %% [markdown]
# Token Analytics

# %%
def token_analysis(tokens):
    total = len(tokens)
    unique = len(set(tokens))
    avg_len = sum(len(t) for t in tokens) / total if total > 0 else 0
    return total, unique, avg_len

for sentence in test_sentences:
    tokens, clean = preprocess_text(sentence)
    t, u, l = token_analysis(tokens)
    print("Original text:", sentence)
    print("Total number of tokens:",t)
    print("Unique tokens:",u)
    print("Average length tokens:",l,"\n")
# Out:
# Original text: Get 100% FREE access now!!!
# Total number of tokens: 4
# Unique tokens: 4
# Average length tokens: 4.0
#
# Original text: I absolutely looooved this product 😍😍
# Total number of tokens: 5
# Unique tokens: 5
# Average length tokens: 5.4
#
# Original text: Worst service ever... 0/10
# Total number of tokens: 3
# Unique tokens: 3
# Average length tokens: 5.333333333333333
#
# Original text: Call me at 9876543210
# Total number of tokens: 3
# Unique tokens: 3
# Average length tokens: 2.6666666666666665
#
# Original text: This is THE best course!!!
# Total number of tokens: 5
# Unique tokens: 5
# Average length tokens: 3.8
#
# Original text: Visit https://openai.com now!
# Total number of tokens: 2
# Unique tokens: 2
# Average length tokens: 4.0
#
# Original text: Nooooo this is baaad!!!
# Total number of tokens: 4
# Unique tokens: 4
# Average length tokens: 2.75
#
# Original text: OK OK OK I got it
# Total number of tokens: 6
# Unique tokens: 4
# ...

# %% [markdown]
# Frequency Analysis

# %%
from collections import Counter

all_tokens = []

for sentence in test_sentences:
    tokens, _ = preprocess_text(sentence)
    all_tokens.extend(tokens)

counter = Counter(all_tokens)

print("Top 10 frequent:", counter.most_common(10))
print("Least frequent:", counter.most_common()[-5:])
# Out:
# Top 10 frequent: [('this', 4), ('now', 3), ('i', 3), ('ok', 3), ('is', 2), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1)]
# Least frequent: [('offer', 1), ('am', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %% [markdown]
# Build Full Pipeline

# %%
def full_pipeline(text_list):
    all_tokens = []
    clean_sentences = []
    
    for text in text_list:
        tokens, clean = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(clean)
    
    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }
print(full_pipeline(test_sentences))
# Out:
# {'tokens': ['get', 'free', 'access', 'now', 'i', 'absolutely', 'loved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'me', 'at', 'this', 'is', 'the', 'best', 'course', 'visit', 'now', 'no', 'this', 'is', 'bad', 'ok', 'ok', 'ok', 'i', 'got', 'it', 'win', 'now', 'limited', 'offer', 'i', 'am', 'not', 'happy', 'with', 'this'], 'clean_sentences': ['get free access now', 'i absolutely loved this product', 'worst service ever', 'call me at', 'this is the best course', 'visit now', 'no this is bad', 'ok ok ok i got it', 'win now limited offer', 'i am not happy with this']}
